# %% [markdown]
# <a href="https://colab.research.google.com/github/rparson4/MarsTharsisGlaciers/blob/main/ModelResultPlotP022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# prompt: load MontesSimulationCompile.csv into pandas dataframe and loop through rows checking if column2 values are N, if so, plot them as green circles

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file into a pandas DataFrame.
try:
    # df = pd.read_csv('MontesSimulationCompile.csv')
    df = pd.read_csv('MontesSimulationCompileP022.csv')
except FileNotFoundError:
    print("Error: 'MontesSimulationCompileP022.csv' not found. Please upload the file.")
    df = pd.DataFrame()  # Create an empty DataFrame to avoid further errors

# Check if the DataFrame is empty
if not df.empty:
    # Adjust Accumulation values to match those used in simulation
    df['Accum. Rate (mm/yr)'] = df['Accum. Rate (mm/yr)']
    # Loop through the rows of the DataFrame.
    for index, row in df.iterrows():
        # Check if the value in 'column2' is 'N'.
        #print(row['Crit Obliq'][1])
        if row['Crit Obliq'][1]=='3':
          if row['Within FSD'] == 'Y' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bo')
            else:
              if row['Heat Flux (mW/m2)'] < 40: # Plot 30 mW/m2 heat flux results
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bo',alpha=0.4, markersize=13)
              else:
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'co',alpha=0.4, markersize=20)
          if row['Within FSD'] == 'N' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bv')
            else:
              if row['Heat Flux (mW/m2)'] < 40: # Plot 30 mW/m2 heat flux results
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bv',alpha=0.4, markersize=13)
              else:
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'cv',alpha=0.4, markersize=20)

          if row['Within FSD'] == 'Y' and row['Ice left']=='N':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'ro')
            else:
              if row['Heat Flux (mW/m2)'] < 40: # Plot 30 mW/m2 heat flux results
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'ro',alpha=0.4, markersize=13)
              else:
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'yo',alpha=0.4, markersize=20)
          if row['Within FSD'] == 'N' and row['Ice left']=='N' or row['Ice left']==np.nan:
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'rv')
            else:
              if row['Heat Flux (mW/m2)'] < 40: # Plot 30 mW/m2 heat flux results
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'rv',alpha=0.4, markersize=13)
              else:
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'yv',alpha=0.4, markersize=20)
    # Show the plot.
    plt.xlabel("Debris Thick (m)")  # Replace with actual column name
    plt.ylabel("Accum. Rate (mm/yr)")  # Replace with actual column name
    plt.title("Crit Obliq = 43")
    xlims = [.025,2.1]
    ylims = [3,100]
    plt.grid(True)
    plt.xlim(xlims)
    plt.ylim(ylims)
    plt.show()

# %%
    # Loop through the rows of the DataFrame.
    for index, row in df.iterrows():
        # Check if the value in 'column2' is 'N'.
        #print(row['Crit Obliq'][1])
        if row['Crit Obliq'][1]=='5':
          if row['Within FSD'] == 'Y' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bo')
            else:
              if row['Heat Flux (mW/m2)'] < 40: # Plot 30 mW/m2 heat flux results
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bo',alpha=0.4, markersize=13)
              else:
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'co',alpha=0.4, markersize=20)
          if row['Within FSD'] == 'N' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bv')
            else:
              if row['Heat Flux (mW/m2)'] < 40: # Plot 30 mW/m2 heat flux results
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bv',alpha=0.4, markersize=13)
              else:
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'cv',alpha=0.4, markersize=20)

          if row['Within FSD'] == 'Y' and row['Ice left']=='N':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'ro')
            else:
              if row['Heat Flux (mW/m2)'] < 40: # Plot 30 mW/m2 heat flux results
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'ro',alpha=0.4, markersize=13)
              else:
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'yo',alpha=0.4, markersize=20)
          if row['Within FSD'] == 'N' and row['Ice left']=='N' or row['Ice left']==np.nan:
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'rv')
            else:
              if row['Heat Flux (mW/m2)'] < 40: # Plot 30 mW/m2 heat flux results
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'rv',alpha=0.4, markersize=13)
              else:
                plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'yv',alpha=0.4, markersize=20)
    # Show the plot.
    plt.xlabel("Debris Thick (m)")  # Replace with actual column name
    plt.ylabel("Accum. Rate (mm/yr)")  # Replace with actual column name
    plt.title("Crit Obliq = 45")
    plt.grid(True)
    xlims = [.025,2.1]
    ylims = [3,100]
    plt.xlim(xlims)
    plt.ylim(ylims)
    plt.show()

# %%
    for index, row in df.iterrows():
        # Check if the value in 'column2' is 'N'.
        #print(row['Crit Obliq'][1])
        if row['Crit Obliq'][1]=='0':
          if row['Within FSD'] == 'Y' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bo')
            else:
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bo',alpha=0.4, markersize=13)
          if row['Within FSD'] == 'N' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bv')
            else:
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bv',alpha=0.4, markersize=13)
          if row['Within FSD'] == 'Y' and row['Ice left']=='N':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'ro')
            else:
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'ro',alpha=0.4, markersize=13)
          if row['Within FSD'] == 'N' and row['Ice left']=='N' or row['Ice left']== np.nan:
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'rv')
            else:
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'rv',alpha=0.4, markersize=13)
    # Show the plot.
    plt.xlabel("Debris Thick (m)")  # Replace with actual column name
    plt.ylabel("Accum. Rate (mm/yr)")  # Replace with actual column name
    plt.title("Crit Obliq = 40")
    plt.grid(True)
    plt.xlim(xlims)
    plt.ylim(ylims)
    plt.show()

# %%
    for index, row in df.iterrows():
        # Check if the value in 'column2' is 'N'.
        #print(row['Crit Obliq'][1])
        if row['Crit Obliq'][1]=='3':
          if row['Within FSD'] == 'Y' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bo')

          if row['Within FSD'] == 'N' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bv')

          if row['Within FSD'] == 'Y' and row['Ice left']=='N':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'ro')

          if row['Within FSD'] == 'N' and row['Ice left']=='N' or row['Ice left']== np.nan:
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'rv')
    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 6./(x45**1.2) + 0.4*x45**1.6 +2.5
    plt.plot(x45,y45,color="steelblue",linestyle=':')
    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 8./((x45-0.1)**1.5) - 1.2*(x45-0.1)**1.0 +7.5
    plt.plot(x45,y45,color="chocolate",linestyle=':')
    # Show the plot.
    plt.xlabel("Debris Thick (m)")  # Replace with actual column name
    plt.ylabel("Accum. Rate (mm/yr)")  # Replace with actual column name
    plt.title("Pavonis; Crit Obliq = 43")
    plt.grid(True)
    plt.xlim(xlims)
    # plt.ylim(ylims)
    plt.show()

# %%
    for index, row in df.iterrows():
        # Check if the value in 'column2' is 'N'.
        #print(row['Crit Obliq'][1])
        if row['Crit Obliq'][1]=='5':
          if row['Within FSD'] == 'Y' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bo')

          if row['Within FSD'] == 'N' and row['Ice left']=='Y':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'bv')

          if row['Within FSD'] == 'Y' and row['Ice left']=='N':
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'ro')

          if row['Within FSD'] == 'N' and row['Ice left']=='N' or row['Ice left']== np.nan:
            # Check location
            if row['Location'] == 'Pavonis':
              # Plot the row as a green circle.  You'll need to decide which columns
              plt.plot(row['Debris Thick (m)'], row['Accum. Rate (mm/yr)'], 'rv')

    # Plot a fitted line
    x45 = np.linspace(1.25, 2.1, 100)
    y45 = 13./(x45**1.4) + 0.8*x45**1.9 +4
    plt.plot(x45,y45,color="steelblue",linestyle='--')
    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 25./((x45+0.1)**1.8) - 0.3*(x45+0.1) +38
    plt.plot(x45,y45,color="chocolate",linestyle='--')
    # Show the plot.
    plt.xlabel("Debris Thick (m)")  # Replace with actual column name
    plt.ylabel("Accum. Rate (mm/yr)")  # Replace with actual column name
    plt.title("Pavonis; Crit Obliq = 45")
    plt.grid(True)
    plt.xlim(xlims)
    plt.ylim(ylims)
    plt.show()

# %%
    plt.figure(figsize=(8, 4))
    # Plot a fitted line
    x45 = np.linspace(0, 2.1, 100)
    y45 = np.ones(len(x45))*32
    plt.plot(x45,y45,color="k",linestyle='--',label=r'Forget et al. (2006)')
    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 25./((x45+0.1)**1.8) - 0.3*(x45+0.1) +38
    plt.plot(x45,y45,color="chocolate",linestyle='--',label=r'P022, 45$^\circ$ crit obliq')
    # Plot a fitted line
    x45 = np.linspace(1.25, 2.1, 100)
    y45 = 13./(x45**1.4) + 0.8*x45**1.9 +4
    plt.plot(x45,y45,color="steelblue",linestyle='--',label=r'P000, 45$^\circ$ crit obliq')

    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 8./((x45-0.1)**1.5) - 1.2*(x45-0.1)**1.0 +7.5
    plt.plot(x45,y45,color="chocolate",linestyle=':',label=r'P022, 43$^\circ$ crit obliq')
    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 6./(x45**1.2) + 0.4*x45**1.6 +2.5
    plt.plot(x45,y45,color="steelblue",linestyle=':',label=r'P000, 43$^\circ$ crit obliq')


    # Show the plot.
    plt.xlabel("Debris Thick (m)")  # Replace with actual column name
    plt.ylabel("Accum. Rate (mm/yr)")  # Replace with actual column name
    plt.title("Pavonis Max Accum. Rate")
    plt.grid(True)
    plt.legend(loc='center left')
    plt.xlim(xlims)
    plt.ylim(0,80)
    plt.show()

# %%
    plt.figure(figsize=(7.5, 4.5), dpi=150)
    # Plot a fitted line
    x45 = np.linspace(0, 2.1, 100)
    y45 = np.ones(len(x45))*32
    plt.plot(x45,y45,color="blue",linestyle='--',label=r'Forget et al. (2006)')
    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 25./((x45+0.1)**1.8) - 0.3*(x45+0.1) +38
    plt.plot(x45,y45,color="red",linestyle='--',label=r'P022, 45$^\circ$ crit obliq')
    # Plot a fitted line
    x45 = np.linspace(1.25, 2.1, 100)
    y45 = 13./(x45**1.4) + 0.8*x45**1.9 +4
    plt.plot(x45,y45,color="black",linestyle='--',label=r'P000, 45$^\circ$ crit obliq')

    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 8./((x45-0.1)**1.5) - 1.2*(x45-0.1)**1.0 +7.5
    plt.plot(x45,y45,color="red",linestyle=':',label=r'P022, 43$^\circ$ crit obliq')
    # Plot a fitted line
    x45 = np.linspace(0.75, 2.1, 100)
    y45 = 6./(x45**1.2) + 0.4*x45**1.6 +2.5
    plt.plot(x45,y45,color="black",linestyle=':',label=r'P000, 43$^\circ$ crit obliq')


    # Show the plot.
    plt.xlabel("Debris Thick (m)")  # Replace with actual column name
    plt.ylabel("Accum. Rate (mm/yr)")  # Replace with actual column name
    plt.title("Pavonis Max Accum. Rate")
    plt.grid(True)
    plt.legend(loc='upper left')
    plt.xlim(xlims)
    plt.ylim(0,80)
    plt.show()
